# %%
import os, sys
import os.path as osp
root_dir = osp.dirname(osp.dirname(osp.dirname(os.getcwd())))
sys.path.append(osp.join(root_dir, 'src'))
from ml_modules.data import deepstabp_col
from ml_modules.data.retrievers import UniProt_Retriever

import numpy as np
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

retr = UniProt_Retriever()

# %%
prefix = 'cell'

filename = f'{prefix}.csv'
file_path = osp.join(deepstabp_col, filename)
accessions = np.loadtxt(
    file_path, usecols=0, skiprows=1, dtype=np.str_, delimiter=','
)

# file_path = '/Users/sebastian/Dropbox/projects/ai-thermostability/code/experiments/testing1/training_entries.txt'
# train_acc = np.loadtxt(file_path, dtype=np.str_, delimiter=',')
# file_path = '/Users/sebastian/Dropbox/projects/ai-thermostability/code/experiments/testing1/validation_entries.txt'
# valid_acc = np.loadtxt(file_path, dtype=np.str_, delimiter=',')

# accessions = np.concatenate(
#     ([a[:-5] for a in train_acc], [a[:-5] for a in valid_acc])
# )
print(accessions)
print(accessions.shape)
# Out:
# ['A0A3B3IS91' 'A0AV96' 'A0AVF1' ... 'R4GMY8' 'R4GN35' 'R4GNH3']
# (11568,)

# %%
successful_accessions, failed_accessions = retr.batch_retrieve(accessions)
# Out:
# R4GNH3      : 100%|##########| 11568/11568 [00:10<00:00, 1138.72it/s]

# %%
mol_weight_count = []
seq_len_count = []
organism_count = {}
interpro_count = {}
organism_tissue_count = {}
keyword_count = {}
reviewed_count = 0

pbar = tqdm(successful_accessions, ascii=True)
for accession in pbar:
    pbar.set_description(accession)

    with open(retr.path_to_data(accession), 'r') as f:
        content = f.readlines()

    all_acc = []
    isoform_acc = []
    tissues = []
    interpro = []
    keywords = []

    id_count = 0
    os_count = 0
    sq_count = 0

    for line in content:
        words = line.split()
        kw = words[0]

        if line.startswith('ID'):
            if id_count == 1:
                raise Exception('Multiple ID lines found')
            id_count += 1

            assert words[3].isdigit()
            seq_len = int(words[3])

            reviewed_count += 1 if words[2] == 'Reviewed;' else 0

        elif line.startswith('AC'):
            all_acc += [w[:-1] for w in words[1:]]

        elif line.startswith('OS'):
            if os_count == 1:
                continue
            os_count += 1

            organism = ' '.join(words[1:3])
        
        elif line.startswith('CC'):
            if words[1].startswith('IsoId'):
                isoform_acc.append(words[1][6:-1])

        elif line.startswith('DR'):
            # print(words)

            if words[1].startswith('InterPro'):
                interpro.append(words[2][:-1])
        
        elif line.startswith('KW'):
            if '{' in line[5:]:
                w = line[5:line.index('{')-1]
                keywords.append(w)
                continue
            elif '}' in line[5:] or '|' in line[5:]:
                continue

            for w in line[5:].split(';'):
                if w[-1] == '\n':
                    w = w[:-1]
                if w == '':
                    continue

                if w[-1] == '.':
                    w = w[:-1]
                if w[0] == ' ':
                    w = w[1:]
                
                keywords.append(w)
        
        elif line.startswith('RC'):
            if words[1].startswith('TISSUE'):
                tissues.append(words[1][7:-1])

        elif line.startswith('SQ'):
            if sq_count == 1:
                raise Exception('Multiple SQ lines found')
            sq_count += 1

            mol_weight = words[4]
            assert mol_weight.isdigit()
            mol_weight = int(mol_weight)

    all_acc = np.unique(all_acc)
    isoform_acc = np.unique(isoform_acc)
    tissues = np.unique(tissues)

    # tally all properties
    seq_len_count.append(seq_len)
    mol_weight_count.append(mol_weight)
    organism_count[organism] = organism_count.get(organism, 0) + 1
    for fam in interpro:
        interpro_count[fam] = interpro_count.get(fam, 0) + 1
    for tissue in tissues:
        tissue_count = organism_tissue_count.get(organism, {})
        organism_tissue_count[organism] = (
            tissue_count | {tissue: tissue_count.get(tissue, 0) + 1}
        )
    for keyword in keywords:
        keyword_count[keyword] = keyword_count.get(keyword, 0) + 1
# Out:
#   0%|          | 0/11528 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots()
bar_container = ax.bar(
    list(organism_count.keys()), list(organism_count.values())
)
ax.bar_label(bar_container, fmt='{:.0f}')
ax.tick_params(labelrotation=45)
ax.set_xlabel('organism')
ax.set_ylabel('count')
# plt.show()
plt.savefig(f'{prefix}-organisms.png', dpi=300, bbox_inches='tight')
plt.close()

keys = ['Membrane', 'Transmembrane', 'Ion channel']
fig, ax = plt.subplots()
bar_container = ax.bar(
    ['All'] + keys,
    [len(successful_accessions)] + [keyword_count[k] for k in keys]
)
ax.bar_label(bar_container, fmt='{:.0f}')
ax.set_xlabel('association')
ax.set_ylabel('count')
# plt.show()
plt.savefig(f'{prefix}-keywords.png', dpi=300, bbox_inches='tight')
plt.close()

plt.hist(seq_len_count, bins=100)
plt.xlabel('sequence length')
plt.ylabel('count')
plt.grid()
# plt.show()
plt.savefig(f'{prefix}-seq_len.png', dpi=300, bbox_inches='tight')
plt.close()

plt.hist(mol_weight_count, bins=100)
plt.xlabel('molecular weight')
plt.ylabel('count')
plt.grid()
# plt.show()
plt.savefig(f'{prefix}-mol_weight.png', dpi=300, bbox_inches='tight')
plt.close()

# %%
keyword_count
# Out:
# {'Direct protein sequencing': 2257,
#  'Nucleus': 3421,
#  'Reference proteome': 10804,
#  'Secreted': 325,
#  '3D-structure': 5787,
#  'Alternative splicing': 5356,
#  'Cytoplasm': 4175,
#  'Methylation': 717,
#  'mRNA processing': 332,
#  'mRNA splicing': 261,
#  'Repeat': 2247,
#  'RNA-binding': 738,
#  'Cell projection': 564,
#  'Ciliopathy': 78,
#  'Cilium': 117,
#  'Disease variant': 2034,
#  'Protein transport': 561,
#  'TPR repeat': 126,
#  'Transport': 1279,
#  'Activator': 414,
#  'Cell cycle': 560,
#  'DNA-binding': 996,
#  'Phosphoprotein': 5661,
#  'Repressor': 432,
#  'Transcription': 1306,
#  'Transcription regulation': 1242,
#  'Acetylation': 2954,
#  'ATP-binding': 1413,
#  'Ligase': 232,
#  'Nucleotide-binding': 1768,
#  'Ubl conjugation pathway': 501,
#  'Calcium': 312,
#  'Cell membrane': 1205,
#  'Endocytosis': 100,
#  'Endoplasmic reticulum': 743,
#  'Lipid transport': 89,
#  'Lipid-binding': 158,
#  'Membrane': 3011,
#  'Metal-binding': 2339,
#  'Transmembrane': 1591,
#  'Transmembrane helix': 1583,
#  'Coiled coil': 1329,
#  'Endosome': 404,
#  'Cytoskeleton': 885,
#  'Developmental protein': 321,
#  'GTPase activation': 136,
#  'SH3 domain': 152,
#  'Glycoprotein': 1006,
#  'Ion transport': 189,
#  'Zinc': 1258,
#  'Zinc-finger': 843,
#  'Fatty acid metabolism': 125,
#  'Lipid metabolism': 451,
#  'Lyase': 236,
#  'Magnesium': 642,
#  'Thiamine pyrophosphate': 20,
#  'Disulfide bond': 735,
#  'Mitochondrion': 979,
#  'Primary mitochondrial disease': 148,
#  'Cell junction': 203,
#  'Differentiation': 281,
#  '4Fe-4S': 95,
#  'Iron': 293,
#  'Iron-sulfur': 131,
#  'Proteomics identification': 425,
#  'Cilium biogenesis/degradation': 99,
#  'Hydrolase': 1333,
#  'Protein phosphatase': 89,
#  'ANK repeat': 132,
#  'Chromosome': 405,
#  'Isopeptide bond': 1314,
#  'Ubl conjugation': 1726,
#  'Dwarfism': 125,
#  'WD repeat': 227,
#  'Aminoacyl-tRNA synthetase': 77,
#  'Protein biosynthesis': 205,
#  'Dioxygenase': 56,
#  'Oxidoreductase': 544,
#  'tRNA processing': 166,
#  'Guanine-nucleotide releasing factor': 109,
#  'Isomerase': 203,
#  'Signal': 806,
#  'Wnt signaling pathway': 93,
#  'Peroxisome': 84,
#  'Transit peptide': 495,
#  'GTP-binding': 300,
#  'Ribosome biogenesis': 140,
#  'Leucine-rich repeat': 112,
#  'Postsynaptic cell membrane': 37,
#  'Synapse': 205,
#  'DNA damage': 378,
#  'DNA recombination': 76,
#  'DNA repair': 332,
#  'Endonuclease': 67,
#  'Nuclease': 125,
#  'Autism spectrum disorder': 33,
#  'Holoprosencephaly': 4,
#  'Intellectual disability': 474,
#  'RNA-mediated gene silencing': 45,
#  'Translation regulation': 114,
#  'Golgi apparatus': 554,
#  'Stress response': 144,
#  'Autophagy': 124,
#  'Cytoplasmic vesicle': 387,
#  'Lipoprotein': 343,
#  'Microtubule': 212,
#  'Carbohydrate metabolism': 112,
#  'Chromatin regulator': 244,
#  'Hydroxylation': 72,
#  'Kelch repeat': 38,
#  'DNA-directed RNA polymerase': 43,
#  'Chaperone': 219,
#  'Actin-binding': 197,
#  'Spermatogenesis': 92,
#  'Lipid biosynthesis': 153,
#  'Phospholipid biosynthesis': 47,
#  'Phospholipid metabolism': 54,
#  'Hypogonadotropic hypogonadism': 8,
#  'Kallmann syndrome': 5,
#  'Microphthalmia': 13,
#  'Methyltransferase': 209,
#  'S-adenosyl-L-methionine': 221,
#  'Transferase': 1656,
#  'Acyltransferase': 143,
#  'SH2 domain': 66,
#  'Tight junction': 45,
#  'Cell division': 374,
#  'Mitosis': 232,
#  'NAD': 212,
#  'Calmodulin-binding': 94,
#  'Glycogen metabolism': 19,
#  'ECO:0000256|RuleBase:RU364123}; Membrane': 1,
#  'Prenylation': 107,
#  'DNA replication': 115,
#  'DNA-directed DNA polymerase': 23,
#  'Nucleotidyltransferase': 107,
#  'Initiation factor': 58,
#  'Cell adhesion': 150,
#  'Collagen': 13,
#  'Extracellular matrix': 44,
#  'Rotamase': 36,
#  'Bait region': 2,
#  'Protease inhibitor': 31,
#  'Serine protease inhibitor': 21,
#  'Thioester bond': 6,
#  'Helicase': 153,
#  'Centromere': 122,
#  'Kinetochore': 92,
#  'Ribonucleoprotein': 341,
#  'Ribosomal protein': 235,
#  'rRNA-binding': 78,
#  'Meiosis': 53,
#  'Spliceosome': 129,
#  'Protease': 282,
#  'Thiol protease': 107,
#  'Manganese': 204,
#  'Adaptive immunity': 74,
#  'Immunity': 281,
#  'Motor protein': 89,
#  'Myosin': 29,
#  'Mitochondrion outer membrane': 99,
#  'ER-Golgi transport': 90,
#  'Fatty acid biosynthesis': 56,
#  'Deafness': 135,
#  'Hearing': 18,
#  'Non-syndromic deafness': 55,
#  'Retinitis pigmentosa': 52,
#  'Usher syndrome': 5,
#  'Exocytosis': 37,
#  'Kinase': 544,
#  'Sushi': 9,
#  'ECO:0000256|RuleBase:RU361148}; Hydrolase': 1,
#  'Notch signaling pathway': 22,
#  'ECO:0000256|RuleBase:RU361148}; Protease': 1,
#  'Apoptosis': 306,
#  'Congenital myasthenic syndrome': 8,
#  'Rule:MF_03007}; Phosphoprotein': 1,
#  'Rule:MF_03005}; Phosphoprotein': 1,
#  'NADP': 194,
#  'Prenyltransferase': 7,
#  'Chromosomal rearrangement': 192,
#  'G-protein coupled receptor': 33,
#  'Receptor': 204,
#  'Transducer': 67,
#  'Nucleosome core': 14,
#  'Phagocytosis': 16,
#  'SH3-binding': 44,
#  'ECO:0007829|MaxQB:B4E0T2}; Receptor': 1,
#  'ECO:0000256|RuleBase:RU004560}; Membrane': 1,
#  'ProRule:PRU00283}; Motor protein': 1,
#  'Aminotransferase': 35,
#  'Ion channel': 61,
#  'Voltage-gated channel': 20,
#  'ProRule:PRU00202}; Golgi apparatus': 1,
#  'Homeobox': 39,
#  'Flagellum': 43,
#  'Gastrulation': 5,
#  'Decarboxylase': 24,
#  'Multifunctional enzyme': 91,
#  'Purine biosynthesis': 37,
#  'Signalosome': 11,
#  'Cardiomyopathy': 49,
#  'Mitochondrion inner membrane': 214,
#  'Neurodegeneration': 288,
#  'Sensory transduction': 44,
#  'Vision': 32,
#  'Glycosidase': 62,
#  'Calcium channel': 18,
#  'Calcium transport': 35,
#  'ECO:0000256|SAM:Phobius}; Transport': 6,
#  'Signal-anchor': 155,
#  'Sulfation': 12,
#  'Protein kinase inhibitor': 6,
#  'Angiogenesis': 58,
#  'ProRule:PRU10141}; Cell junction': 1,
#  'Tyrosine-protein kinase': 47,
#  'Proto-oncogene': 122,
#  'Aminopeptidase': 38,
#  'Metalloprotease': 78,
#  'HDL': 4,
#  'ProRule:PRU00023}; GTPase activation': 1,
#  'Age-related macular degeneration': 7,
#  'Cataract': 54,
#  'Cockayne syndrome': 7,
#  'Neurogenesis': 119,
#  'Xeroderma pigmentosum': 9,
#  'Dynein': 24,
#  'Chloride': 24,
#  'Chloride channel': 13,
#  'Ligand-gated ion channel': 12,
#  'ECO:0007829|ProteomicsDB:E9PBQ7}; Receptor': 1,
#  'LIM domain': 43,
#  'Nonsense-mediated mRNA decay': 32,
#  'ECO:0000256|RuleBase:RU369098}; Nucleus': 1,
#  'ProRule:PRU00283}; Coiled coil': 1,
#  'ProRule:PRU10141}; Calmodulin-binding': 1,
#  'Coated pit': 43,
#  'Heme': 57,
#  'FAD': 112,
#  'Flavoprotein': 140,
#  'Nickel': 14,
#  'Growth factor': 23,
#  'Heparin-binding': 16,
#  'Mitogen': 9,
#  'Elongation factor': 24,
#  'Serine/threonine-protein kinase': 263,
#  'Electron transport': 92,
#  'Respiratory chain': 47,
#  'Hydrogen ion transport': 30,
#  'Molybdenum': 11,
#  'Molybdenum cofactor biosynthesis': 16,
#  'ProRule:PRU00331}; Nucleus': 1,
#  'Rule:MF_03175}; Cytoplasm': 1,
#  'Zymogen': 63,
#  'Intermediate filament': 13,
#  'Immunoglobulin domain': 102,
#  'Exonuclease': 55,
#  'mRNA transport': 90,
#  'Leukodystrophy': 37,
#  'Necrosis': 12,
#  'Oxygen transport': 10,
#  'Peroxisome biogenesis': 11,
#  'Peroxisome biogenesis disorder': 15,
#  'Zellweger syndrome': 13,
#  'Palmitate': 126,
#  'Phenylalanine catabolism': 4,
#  'Tyrosine catabolism': 4,
#  'ProRule:PRU10141}; Kinase': 4,
#  'Laminin EGF-like domain': 8,
#  'CBS domain': 30,
#  'ProRule:PRU00221}; Wnt signaling pathway': 1,
#  'Alternative initiation': 98,
#  'Antiviral defense': 75,
#  'rRNA processing': 155,
#  'Pyridoxal phosphate': 96,
#  'ProRule:PRU00176}; Zinc': 1,
#  'Metal-thiolate cluster': 3,
#  'ProRule:PRU00202}; Reference proteome': 1,
#  'Nuclear pore complex': 42,
#  'Translocation': 73,
#  'ECO:0000256|RuleBase:RU364035}; Transport': 1,
#  'ProRule:PRU00192}; Synapse': 1,
#  'Hypusine': 4,
#  'Host-virus interaction': 490,
#  'Microsome': 40,
#  'ProRule:PRU10141}; Carbohydrate metabolism': 1,
#  'ProRule:PRU10141}; Cell projection': 1,
#  'Rule:MF_03167}; Cytoplasm': 1,
#  'Rule:MF_03167}; Nucleus': 1,
#  'Biological rhythms': 87,
#  'ProRule:PRU10141}; Cytoplasm': 1,
#  'Serine protease': 33,
#  'Rule:MF_03120}; Transit peptide': 1,
#  'ProRule:PRU01077}; Metal-binding': 1,
#  'DNA synthesis': 11,
#  'Lysosome': 226,
#  'Rhizomelic chondrodysplasia punctata': 4,
#  'Lissencephaly': 21,
#  'Progressive external ophthalmoplegia': 9,
#  'Serine esterase': 18,
#  'Synaptosome': 23,
#  'Sarcoplasmic reticulum': 25,
#  'Cushing syndrome': 8,
#  'Chemotaxis': 23,
#  'Lectin': 32,
#  'Albinism': 13,
#  'Hermansky-Pudlak syndrome': 11,
#  'Translocase': 91,
#  'Ubiquinone': 15,
#  'Proteasome': 58,
#  'Copper': 32,
#  'Copper transport': 5,
#  'Steroid-binding': 3,
#  'Glutathionylation': 8,
#  'Inflammatory response': 52,
#  'Innate immunity': 188,
#  'Lipoyl': 5,
#  'Congenital hypothyroidism': 3,
#  'Hereditary spastic paraplegia': 47,
#  'S-nitrosylation': 45,
#  'EGF-like domain': 49,
#  'Heparan sulfate': 5,
#  'Proteoglycan': 16,
#  'Osteogenesis imperfecta': 15,
#  'Vitamin C': 12,
#  'ADP-ribosylation': 74,
#  'Leigh syndrome': 14,
#  'Viral penetration into host nucleus': 2,
#  'Virus entry into host cell': 4,
#  'Tumor suppressor': 110,
#  'Spinocerebellar ataxia': 27,
#  'Chromosome partition': 45,
#  'Inflammasome': 5,
#  'Glycosyltransferase': 148,
#  'Ichthyosis': 25,
#  'Nucleotide metabolism': 28,
#  'Pyrrolidone carboxylic acid': 14,
#  'Allosteric enzyme': 62,
#  'Biotin': 9,
#  'Charcot-Marie-Tooth disease': 37,
#  'Cobalt': 36,
#  'Neuropathy': 87,
#  'Sodium': 36,
#  'Ubiquinone biosynthesis': 15,
#  'Growth regulation': 32,
#  'Signal transduction inhibitor': 20,
#  'Myogenesis': 22,
#  'Phosphopantetheine': 6,
#  'Primary microcephaly': 32,
#  'Olfaction': 7,
#  'SCID': 14,
#  'Epilepsy': 174,
#  'Dystonia': 23,
#  'Alzheimer disease': 11,
#  'Amyloidosis': 12,
#  'Cleavage on pair of basic residues': 45,
#  'Biomineralization': 6,
#  'Autocatalytic cleavage': 28,
#  'Neuronal ceroid lipofuscinosis': 9,
#  'Autism': 11,
#  'Congenital muscular dystrophy': 18,
#  'Dystroglycanopathy': 11,
#  'Vacuole': 26,
#  'Limb-girdle muscular dystrophy': 20,
#  'Actin capping': 16,
#  'Glutamine amidotransferase': 32,
#  'Alternative promoter usage': 47,
#  'Cholesterol metabolism': 47,
#  'Host cell receptor for virus entry': 36,
#  'Niemann-Pick disease': 3,
#  'Steroid metabolism': 63,
#  'Sterol metabolism': 56,
#  'Congenital generalized lipodystrophy': 4,
#  'Diabetes mellitus': 40,
#  'Myristate': 100,
#  'Bromodomain': 30,
#  'Joubert syndrome': 18,
#  'Leber congenital amaurosis': 8,
#  'Nephronophthisis': 13,
#  'Senior-Loken syndrome': 5,
#  'Sphingolipid metabolism': 18,
#  'Fanconi anemia': 16,
#  'Pharmaceutical': 12,
#  'Congenital disorder of glycosylation': 47,
#  'Oxidation': 25,
#  'Symport': 29,
#  'Amino-acid biosynthesis': 151,
#  'Branched-chain amino acid biosynthesis': 21,
#  'Aortic aneurysm': 5,
#  'Premature ovarian failure': 9,
#  'Tumor antigen': 16,
#  'mRNA capping': 8,
#  'Serine biosynthesis': 8,
#  'Lipid droplet': 45,
#  'Allergen': 4,
#  'GPI-anchor biosynthesis': 15,
#  'Redox-active center': 58,
#  'Parkinson disease': 17,
#  'Parkinsonism': 28,
#  'tRNA-binding': 57,
#  'Amidation': 2,
#  'Neuropeptide': 2,
#  'Oncogene': 6,
#  'Williams-Beuren syndrome': 13,
#  'Protein phosphatase inhibitor': 11,
#  'Antiport': 26,
#  'Tricarboxylic acid cycle': 42,
#  'One-carbon metabolism': 32,
#  'GPI-anchor': 18,
#  'Cell shape': 44,
#  'Growth arrest': 9,
#  'cGMP': 4,
#  'Amelogenesis imperfecta': 6,
#  'Lysine biosynthesis': 16,
#  'Nucleotide biosynthesis': 13,
#  'cAMP biosynthesis': 2,
#  'Obesity': 31,
#  'Hirschsprung disease': 3,
#  'Oogenesis': 7,
#  'Transmembrane beta strand': 6,
#  'Alport syndrome': 3,
#  'Elliptocytosis': 6,
#  'Hereditary hemolytic anemia': 33,
#  'Cyclin': 18,
#  'Selenocysteine': 12,
#  'Ectodermal dysplasia': 24,
#  'Dyskeratosis congenita': 7,
#  'Telomere': 37,
#  'Osteopetrosis': 6,
#  'Waardenburg syndrome': 1,
#  'Myofibrillar myopathy': 7,
#  'Xylose metabolism': 4,
#  'Hypotrichosis': 14,
#  'Intrahepatic cholestasis': 8,
#  'Hyaluronic acid': 1,
#  'Amino-acid transport': 37,
#  'Unfolded protein response': 24,
#  'Citrullination': 35,
#  'DNA replication inhibitor': 2,
#  'B-cell activation': 5,
#  'Atrial fibrillation': 3,
#  'Aicardi-Goutieres syndrome': 8,
#  'Antiviral protein': 1,
#  'Steroid biosynthesis': 34,
#  'Sterol biosynthesis': 26,
#  'Glyoxylate bypass': 9,
#  'CF(0)': 7,
#  'ATP synthesis': 10,
#  'Carboxypeptidase': 19,
#  'Diabetes insipidus': 1,
#  'Mitochondrion nucleoid': 18,
#  'Cholesterol biosynthesis': 18,
#  'Sodium transport': 27,
#  'Signal recognition particle': 9,
#  'Thiol protease inhibitor': 6,
#  'Craniosynostosis': 14,
#  'Lipid degradation': 52,
#  'Monooxygenase': 19,
#  'Nitration': 32,
#  'Systemic lupus erythematosus': 9,
#  'Amyotrophic lateral sclerosis': 31,
#  'DNA condensation': 11,
#  'Cytokine': 14,
#  'Desmin-related myopathy': 2,
#  'Atherosclerosis': 5,
#  'Glucose metabolism': 20,
#  'FMN': 42,
#  'Palmoplantar keratoderma': 11,
#  'Isoprene biosynthesis': 20,
#  'Erythrocyte maturation': 2,
#  'Lithium': 4,
#  'Topoisomerase': 11,
#  'Aspartyl protease': 4,
#  'Li-Fraumeni syndrome': 1,
#  'Leber hereditary optic neuropathy': 6,
#  'Glycogen storage disease': 17,
#  'Gluconate utilization': 4,
#  'Pentose shunt': 5,
#  'Methotrexate resistance': 2,
#  'Cell inner membrane': 156,
#  'Hydrogen peroxide': 4,
#  'Organic radical': 2,
#  'Peroxidase': 22,
#  'Antioxidant': 13,
#  'Arginine biosynthesis': 16,
#  'Urea cycle': 5,
#  'Purine salvage': 10,
#  'Gout': 2,
#  'Threonine biosynthesis': 5,
#  'Glycolysis': 46,
#  'Blood coagulation': 8,
#  'Fibrinolysis': 2,
#  'Hemostasis': 8,
#  'Kringle': 3,
#  'Thrombophilia': 3,
#  'Tissue remodeling': 1,
#  'Periplasm': 79,
#  'Antibiotic resistance': 22,
#  'Aromatic amino acid biosynthesis': 26,
#  'Tryptophan biosynthesis': 10,
#  'Folate biosynthesis': 7,
#  'Chromophore': 3,
#  'Methionine biosynthesis': 21,
#  'Asparagine biosynthesis': 5,
#  'Metalloenzyme inhibitor': 3,
#  'Metalloprotease inhibitor': 2,
#  'Amyloid': 9,
#  'LDL': 3,
#  'Hormone': 4,
#  'Immunoglobulin': 3,
#  'T cell receptor': 1,
#  'Eye lens protein': 1,
#  'Emery-Dreifuss muscular dystrophy': 6,
#  'Pyropoikilocytosis': 2,
#  'Glycation': 7,
#  'Chylomicron': 3,
#  'Hyperlipidemia': 2,
#  'VLDL': 5,
#  'Acute phase': 1,
#  'Iron transport': 14,
#  'Antibiotic': 3,
#  'Antimicrobial': 4,
#  'Osteogenesis': 8,
#  'Iron storage': 2,
#  'Gamma-carboxyglutamic acid': 2,
#  'Sugar transport': 28,
#  'Galactose metabolism': 9,
#  'MELAS syndrome': 3,
#  'Terminal addition': 1,
#  'Gaucher disease': 2,
#  'Schiff base': 14,
#  'GMP biosynthesis': 6,
#  'Annexin': 8,
#  'Calcium/phospholipid-binding': 10,
#  'Phospholipase A2 inhibitor': 2,
#  'RNA editing': 10,
#  'Pseudohermaphroditism': 1,
#  'Prion': 2,
#  'von Willebrand disease': 1,
#  'Glutathione biosynthesis': 6,
#  'Cadmium': 3,
#  'Anion exchange': 3,
#  'Lipopolysaccharide biosynthesis': 28,
#  'Isoleucine biosynthesis': 2,
#  'Pyrimidine biosynthesis': 17,
#  'Potassium': 51,
#  'Potassium transport': 23,
#  'Primary hypomagnesemia': 2,
#  'Sodium/potassium transport': 5,
#  'Integrin': 12,
#  'Steroidogenesis': 4,
#  'Plasminogen activation': 2,
#  'Pyridoxine biosynthesis': 6,
#  'Restriction system': 3,
#  'Keratin': 2,
#  '2Fe-2S': 27,
#  'Vitamin D': 1,
#  'Heme biosynthesis': 17,
#  'Porphyrin biosynthesis': 18,
#  'Quinone': 11,
#  'Corneal dystrophy': 6,
#  'Ribosomal frameshifting': 5,
#  'Gluconeogenesis': 14,
#  'Muscle protein': 19,
#  'Nemaline myopathy': 3,
#  'Gangliosidosis': 5,
#  'RNA repair': 2,
#  'Bacterial flagellum': 3,
#  'Flagellar rotation': 5,
#  'Histidine biosynthesis': 16,
#  'Proline biosynthesis': 10,
#  'Primosome': 8,
#  'Tyrosine biosynthesis': 1,
#  'Aromatic hydrocarbons catabolism': 4,
#  'Detoxification': 7,
#  'Catecholamine biosynthesis': 2,
#  'Neurotransmitter biosynthesis': 2,
#  'Leucine biosynthesis': 6,
#  'Basement membrane': 10,
#  'Complement alternate pathway': 4,
#  'Complement pathway': 9,
#  'Cytolysis': 4,
#  'Membrane attack complex': 3,
#  'Retinol-binding': 3,
#  'Two-component regulatory system': 32,
#  'Lactose biosynthesis': 1,
#  'Keratinization': 2,
#  'Metachromatic leukodystrophy': 4,
#  'Congenital erythrocytosis': 3,
#  'Cell wall biogenesis/degradation': 40,
#  'Peptidoglycan synthesis': 27,
#  'Blood group antigen': 4,
#  'Nitrate assimilation': 3,
#  'Arabinose catabolism': 3,
#  'Mucopolysaccharidosis': 12,
#  'Mutator protein': 3,
#  'Phosphate transport': 8,
#  'Pyruvate': 12,
#  'Hemolytic uremic syndrome': 3,
#  'Diamond-Blackfan anemia': 16,
#  'Phosphotransferase system': 12,
#  'Polyamine biosynthesis': 7,
#  'Spermidine biosynthesis': 5,
#  'Glycerol metabolism': 11,
#  'Phenylketonuria': 3,
#  'Tetrahydrobiopterin biosynthesis': 5,
#  'Glutamate biosynthesis': 3,
#  'Leukotriene biosynthesis': 5,
#  'Biotin biosynthesis': 5,
#  'Coenzyme A biosynthesis': 9,
#  'Diaminopimelate biosynthesis': 6,
#  'Septation': 9,
#  'Glycogen biosynthesis': 7,
#  'Conjugation': 1,
#  'Lipid A biosynthesis': 6,
#  'Pyridine nucleotide biosynthesis': 13,
#  'Transcription antitermination': 7,
#  'SOS response': 8,
#  'Dipeptidase': 6,
#  'Queuosine biosynthesis': 7,
#  'Riboflavin biosynthesis': 6,
#  'Transcription termination': 13,
#  'Selenium': 7,
#  'Tryptophan catabolism': 4,
#  'Formylation': 1,
#  'Menaquinone biosynthesis': 11,
#  'DNA excision': 10,
#  'Excision nuclease': 4,
#  'Virulence': 2,
#  'Cysteine biosynthesis': 10,
#  'Pantothenate biosynthesis': 5,
#  'Phenylalanine biosynthesis': 1,
#  'Fucose metabolism': 7,
#  'Galactitol metabolism': 4,
#  'Peptide transport': 10,
#  'CF(1)': 1,
#  'Plasmid copy control': 1,
#  'Cytochrome c-type biogenesis': 1,
#  'Trimethoprim resistance': 1,
#  '3Fe-4S': 4,
#  'Quorum sensing': 2,
#  'cAMP': 14,
#  'cAMP-binding': 7,
#  'Phospholipid degradation': 2,
#  'Folate-binding': 3,
#  'Enterobactin biosynthesis': 4,
#  'Arginine metabolism': 6,
#  'Cobalamin biosynthesis': 6,
#  'Sigma factor': 3,
#  'Bile acid catabolism': 1,
#  'Nitrogen fixation': 2,
#  'Sulfate transport': 2,
#  'Thiamine biosynthesis': 8,
#  'Toxin-antitoxin system': 6,
#  'Capsule biogenesis/degradation': 2,
#  'Catecholamine metabolism': 3,
#  'Long QT syndrome': 5,
#  'Cell wall': 4,
#  'Thick filament': 5,
#  'Maple syrup urine disease': 3,
#  'Stickler syndrome': 2,
#  'Collagen degradation': 2,
#  'Cobalamin': 7,
#  'Bernard Soulier syndrome': 1,
#  'Chronic granulomatous disease': 2,
#  'Atrial septal defect': 2,
#  'Pheromone response': 3,
#  'Glutaricaciduria': 5,
#  'Serine protease homolog': 1,
#  'Prostaglandin metabolism': 6,
#  'Fertilization': 6,
#  'Hereditary nonpolyposis colorectal cancer': 7,
#  'Congenital adrenal hyperplasia': 2,
#  'Intron homing': 1,
#  'Protein splicing': 3,
#  'IgE-binding protein': 1,
#  'Growth factor binding': 6,
#  'Bacterial microcompartment': 2,
#  'Triplet repeat expansion': 14,
#  'c-di-GMP': 4,
#  'Neurotransmitter degradation': 2,
#  'Schizophrenia': 5,
#  'Potassium channel': 6,
#  'Ehlers-Danlos syndrome': 6,
#  'Karyogamy': 1,
#  'Deoxyribonucleotide synthesis': 5,
#  'Epidermolysis bullosa': 6,
#  'Virion': 1,
#  'Cone-rod dystrophy': 15,
#  'Neurotransmitter transport': 8,
#  'RNA-directed RNA polymerase': 1,
#  'Exosome': 9,
#  'Tellurium resistance': 1,
#  'Cobalt transport': 1,
#  'Threonine protease': 6,
#  'Behavior': 3,
#  'Vitamin A': 2,
#  'Proline metabolism': 1,
#  'Melanin biosynthesis': 3,
#  'MHC I': 2,
#  'Ascorbate biosynthesis': 2,
#  'Branched-chain amino acid catabolism': 5,
#  'IgG-binding protein': 1,
#  'Rhamnose metabolism': 1,
#  'Gap junction': 3,
#  'Sporulation': 7,
#  'Polysaccharide degradation': 2,
#  'Purine metabolism': 5,
#  'Chromate resistance': 1,
#  'Tungsten': 1,
#  'Lead': 1,
#  'Zinc transport': 12,
#  'Glaucoma': 6,
#  'Transposition': 3,
#  'Sexual differentiation': 3,
#  'Lactation': 1,
#  'Autoinducer synthesis': 1,
#  'Aspartyl esterase': 1,
#  'Cell outer membrane': 8,
#  'Prostaglandin biosynthesis': 4,
#  'Complement activation lectin pathway': 1,
#  'Hypusine biosynthesis': 2,
#  'Primary ciliary dyskinesia': 13,
#  'Bartter syndrome': 2,
#  'Bacterial flagellum biogenesis': 1,
#  'Bacterial flagellum protein export': 1,
#  'Sialic acid': 3,
#  'Kartagener syndrome': 10,
#  'Plasmid': 46,
#  'Cytoplasmic inwards viral transport': 1,
#  'Microtubular inwards viral transport': 1,
#  'Congenital dyserythropoietic anemia': 9,
#  'Hypotensive agent': 1,
#  'Vasoactive': 1,
#  'PHB biosynthesis': 1,
#  'Covalent protein-DNA linkage': 2,
#  'Cellulose biosynthesis': 1,
#  'DNA integration': 2,
#  'Viral genome integration': 1,
#  'Fimbrium biogenesis': 1,
#  'Hemolysis': 1,
#  'Host cell membrane': 1,
#  'Host membrane': 1,
#  'Toxin': 2,
#  'Xylan degradation': 1,
#  'Sodium channel': 2,
#  'Stargardt disease': 2,
#  'Cystinuria': 1,
#  'Defensin': 1,
#  'Fungicide': 1,
#  'cGMP biosynthesis': 2,
#  'Translational shunt': 1,
#  'Bardet-Biedl syndrome': 14,
#  'Protein synthesis inhibitor': 3,
#  'Inhibition of host innate immune response by virus': 1,
#  'Inhibition of host interferon signaling pathway by virus': 1,
#  'Inhibition of host STAT1 by virus': 1,
#  'Inhibition of host STAT2 by virus': 1,
#  'Viral immunoevasion': 1,
#  'Meckel syndrome': 4,
#  'Viral RNA replication': 2,
#  'Chitin-binding': 1,
#  'Heterotaxy': 3,
#  'Photoreceptor protein': 2,
#  'Neurotransmitter': 1,
#  'Mineral balance': 1,
#  'Mucolipidosis': 1,
#  'Pontocerebellar hypoplasia': 4,
#  'Chondrogenesis': 1,
#  'Asthma': 2,
#  'Congenital stationary night blindness': 2,
#  'ProRule:PRU10141}; Transferase': 1,
#  'Familial hemophagocytic lymphohistiocytosis': 1,
#  'ProRule:PRU01091}; Phosphoprotein': 6,
#  'Rule:MF_00081}; Transcription': 1,
#  'Rule:MF_00983}; DNA replication': 1,
#  'Rule:MF_00983}; Primosome': 1,
#  'Rule:MF_00952}; Zinc': 1,
#  'ECO:0000256|RuleBase:RU003525}; NAD': 1,
#  'Rule:MF_00942}; DNA-binding': 1,
#  'Rule:MF_00942}; Nuclease': 1,
#  'Rule:MF_00146}; Nucleotide-binding': 1,
#  'Rule:MF_00181}; Cytoplasm': 1,
#  'Rule:MF_00365}; Cytoplasm': 1,
#  'Rule:MF_00365}; SOS response': 1,
#  'ECO:0000256|RuleBase:RU003862}; NAD': 1,
#  'Rule:MF_00741}; Cytoplasm': 1,
#  'Rule:MF_00741}; Purine biosynthesis': 1,
#  'ECO:0000313|EMBL:AAS81834.1}; Lyase': 1,
#  'ECO:0000256|RuleBase:RU362081}; Transport': 1,
#  'Rule:MF_00092}; Coiled coil': 1,
#  'Rule:MF_00583}; Cytoplasm': 1,
#  'Rule:MF_00583}; Nucleotide-binding': 1,
#  'ECO:0000256|RuleBase:RU363032}; Transport': 1,
#  'Rule:MF_01898}; Cytoplasm': 1,
#  'ECO:0000256|RuleBase:RU003651}; Cell cycle': 2,
#  'ECO:0000256|RuleBase:RU362085}; Primosome': 1,
#  'Rule:MF_02075}; Cytoplasm': 1,
#  'Rule:MF_02075}; Protein biosynthesis': 1,
#  'Rule:MF_01897}; Coiled coil': 1,
#  'Rule:MF_01228}; Zinc': 1,
#  'Rule:MF_01025}; Manganese': 1,
#  'Rule:MF_00944}; Coiled coil': 1,
#  'Rule:MF_00992}; Menaquinone biosynthesis': 1,
#  'Rule:MF_00992}; Oxidoreductase': 1,
#  'Rule:MF_02033}; Cell inner membrane': 1,
#  'Rule:MF_01283}; Multifunctional enzyme': 1,
#  'Rule:MF_01283}; Zinc': 1,
#  'ProRule:PRU00560}; DNA-binding': 1,
#  'ProRule:PRU00335}; Transcription': 1,
#  'Rule:MF_02040}; Hydrolase': 1,
#  'Rule:MF_00969}; Coiled coil': 1,
#  'Rule:MF_00969}; Helicase': 1,
#  'ProRule:PRU01193}; Repeat': 1,
#  'Rule:MF_00993}; Menaquinone biosynthesis': 1,
#  'Rule:MF_00993}; Transferase': 1,
#  'ProRule:PRU00296}; Iron': 1,
#  'Carbon dioxide fixation': 1,
#  'ECO:0000313|EMBL:AAS80603.1}; Lyase': 1,
#  'ECO:0000256|PIRNR:PIRNR000381}; Repeat': 1,
#  'Rule:MF_02121}; NADP': 1,
#  'ECO:0000256|RuleBase:RU003555}; Hydrolase': 1,
#  'Rule:MF_01498}; Zinc': 1,
#  'ProRule:PRU00492}; Kinase': 1,
#  'ProRule:PRU00492}; Transferase': 1,
#  'Rule:MF_00920}; Membrane': 1,
#  'ECO:0000313|EMBL:AAS80397.1}; Cytoplasm': 1,
#  'Rule:MF_01815}; Multifunctional enzyme': 1,
#  'Rule:MF_00902}; Transport': 1,
#  'ECO:0000256|HAMAP-Rule:MF_00187}; Plasmid': 1,
#  'ECO:0000256|HAMAP-Rule:MF_00028}; Hydrolase': 1,
#  'ECO:0000313|EMBL:AAS82343.1}; Plasmid': 1,
#  'ECO:0000313|EMBL:AAS82340.1}; Plasmid': 1,
#  'ECO:0000256|HAMAP-Rule:MF_00027}; Ligase': 1,
#  'Gaseous exchange': 1,
#  'Surface film': 1,
#  'Brugada syndrome': 1,
#  'Hereditary multiple exostoses': 1,
#  'Porin': 1,
#  'Histidine metabolism': 1,
#  'Thioether bond': 1,
#  'ProRule:PRU00035}; Helicase': 1,
#  'ERV': 1,
#  'Transposable element': 1,
#  'Inositol biosynthesis': 1,
#  'Carnitine biosynthesis': 1,
#  'Activation of host autophagy by virus': 1}
